# %% [markdown]
# ## Scrape Images from Amazon

# %%
import os
import sys

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

from src.scripts.web_scraping_fix import scrape_images_from_file

# %%
input_file = os.path.abspath("../src/data/dataset/combined_cnn_train_data_desc.csv")  # CSV with StockCode, Description
scrape_images_from_file(input_file)
# Out:
# INFO: Processing stock code: 22384
# INFO: [START] search_and_download_images for stock_code=22384, description='LUNCH BAG PINK POLKADOT'
# INFO: [INFO] Files will be saved to: c:\Users\don\dev\ds_test\static\images\22384
# INFO: Loaded existing metadata for 22384 with 50 entries
# INFO: Found 50 existing amazon_*.jpg files
# INFO: Already have 50 images, skipping search
# INFO: Processing stock code: 22727
# INFO: [START] search_and_download_images for stock_code=22727, description='ALARM CLOCK BAKELIKE RED'
# INFO: [INFO] Files will be saved to: c:\Users\don\dev\ds_test\static\images\22727
# INFO: Loaded existing metadata for 22727 with 50 entries
# INFO: Found 50 existing amazon_*.jpg files
# INFO: Already have 50 images, skipping search
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 input_file = os.path.abspath("../src/data/dataset/combined_cnn_train_data_desc.csv")  # CSV with StockCode, Description
# ----> 2 scrape_images_from_file(input_file)
#
# File c:\Users\don\dev\ds_test\src\scripts\web_scraping_fix.py:450, in scrape_images_from_file(input_file)
#     448             logger.error(f"Failed to process {description} (stock code: {stock_code})")
#     449         # Add a delay between products
# --> 450         time.sleep(random.uniform(2, 5))
#     451 except Exception as e:
#     452     logger.error(f"Error in scrape_images_from_file: {str(e)}")
#
# KeyboardInterrupt:
